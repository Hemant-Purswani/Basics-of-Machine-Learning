# %% [markdown]
# #Name: Hemant Manoj Purswani
# #Roll No.: R043
# #Batch: B2

# %% [markdown]
# #Lab 1 Task 2

# %%
import numpy as np
import pandas as pd

#importing libraries

# %%
df=pd.read_csv("indian_food.csv")

#reading a csv file

# %%
df.shape

#No. of Total Dishes
#No.of Dishes
# Out:
# (255, 9)

# %%
df.size

#size of the table
# Out:
# 2295

# %%
df.info()

#gives us the information about like what are, and the data type of the attributes present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  226 non-null    object
#  6   course          255 non-null    object
#  7   state           231 non-null    object
#  8   region          241 non-null    object
#  9   Total Time      255 non-null    int64
#  10  No.of Ing       255 non-null    int64
# dtypes: int64(4), object(7)
# memory usage: 22.0+ KB

# %%
df.head(5)

#gives the information of the first 5 rows
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df.describe()

#High std mean chances of outlier
#when value not given then -1 is given
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
df.isnull()

#checks if there are any null values in the table
# Out:
#       name  ingredients   diet  prep_time  cook_time  flavor_profile  course  \
# 0    False        False  False      False      False           False   False
# 1    False        False  False      False      False           False   False
# 2    False        False  False      False      False           False   False
# 3    False        False  False      False      False           False   False
# 4    False        False  False      False      False           False   False
# ..     ...          ...    ...        ...        ...             ...     ...
# 250  False        False  False      False      False           False   False
# 251  False        False  False      False      False           False   False
# 252  False        False  False      False      False           False   False
# 253  False        False  False      False      False           False   False
# 254  False        False  False      False      False           False   False
#
#      state  region  Total Time  No.of Ing
# ...

# %%
df=df.replace(range(-2,0),'NaN')
print(df)

#Replacing then negative values with NaN
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet prep_time cook_time flavor_profile   course            state  \
# ...

# %%
a=list(df.select_dtypes(include=[np.number]).columns.values)
print(a)

#prints all the features which is numerical in nature
# Out:
# ['prep_time', 'cook_time']

# %%
df.nunique()

#prints the numbers of unique elements in a table column-wise
# Out:
# name              255
# ingredients       252
# diet                2
# prep_time          22
# cook_time          19
# flavor_profile      4
# course              4
# state              24
# region              6
# dtype: int64

# %%
a=df["prep_time"]+df["cook_time"]
df["Total Time"]=a
df.head(255)

#creating a new column Total Time = prep time + cook time
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
#Creating funtion to calculate the number of Ingredients in a dish

def count_ingredients(x):
  y=x.split(",")
  return len(y)

df["No.of Ing"]=df.ingredients.apply(lambda x:count_ingredients(x))
df.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# ...
